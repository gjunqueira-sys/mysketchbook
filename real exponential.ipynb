# %% [markdown]
# # Signal Processing

# %% [markdown]
# ## Real-Value Exponential

# %%
r(a, n) = a^n
# Out:
# r (generic function with 2 methods)

# %%
r_exp = [r(1.1, n) for n in -50:50]
# Out:
# 101-element Array{Float64,1}:
#    0.008518551279500606
#    0.009370406407450668
#    0.010307447048195735
#    0.01133819175301531
#    0.012472010928316842
#    0.013719212021148527
#    0.015091133223263381
#    0.016600246545589722
#    0.018260271200148694
#    0.020086298320163565
#    0.02209492815217992
#    0.02430442096739792
#    0.02673486306413771
#    ⋮
#   41.144777789250995
#   45.2592555681761
#   49.78518112499371
#   54.763699237493086
#   60.2400691612424
#   66.26407607736665
#   72.89048368510332
#   80.17953205361366
#   88.19748525897504
#   97.01723378487253
#  106.7189571633598
#  117.39085287969579

# %%
using Plots

# %%
plot(r_exp, line=:stem, marker=:o)

# %% [markdown]
# For $a > 1$,  $r[n]$, the curve srhrinks to the left and increase to the right.

# %%
r_exp = [r(0.9, n) for n in -50:50]
# Out:
# 101-element Array{Float64,1}:
#  194.03252174826304
#  174.62926957343674
#  157.16634261609306
#  141.44970835448376
#  127.3047375190354
#  114.57426376713185
#  103.11683739041868
#   92.80515365137681
#   83.52463828623914
#   75.17217445761523
#   67.6549570118537
#   60.88946131066833
#   54.8005151796015
#    ⋮
#    0.016423203268260675
#    0.014780882941434606
#    0.013302794647291147
#    0.011972515182562033
#    0.01077526366430583
#    0.009697737297875247
#    0.008727963568087723
#    0.00785516721127895
#    0.007069650490151055
#    0.00636268544113595
#    0.0057264168970223555
#    0.00515377520732012

# %%
plot(r_exp, line=:stem, marker=:o)

# %% [markdown]
# For  $0 < a < 1$ , $r[n]$ grows to the left and shrinks to the right.
